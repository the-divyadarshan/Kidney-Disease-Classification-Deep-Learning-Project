# %%
import os

# %%
# %pwd
# Out:
# 'e:\\KrishNair\\Kidney_Disease_Classification_Deep_Learning_Project\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'e:\\KrishNair\\Kidney_Disease_Classification_Deep_Learning_Project'

# %%
from dataclasses import dataclass
from pathlib import Path


@dataclass(frozen=True)
class DataIngestionConfig:
    root_dir: Path
    source_URL: str
    local_data_file: Path
    unzip_dir: Path

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\PC\.conda\envs\kidney\python.exe

# %%
# %pip show cnnClassifier
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Package(s) not found: cnnClassifier

# %%
# %pip install -e ..
# Out:
# Obtaining file:///E:/KrishNair/Kidney_Disease_Classification_Deep_Learning_Project
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Installing collected packages: cnnClassifier
#   Running setup.py develop for cnnClassifier
# Successfully installed cnnClassifier
# Note: you may need to restart the kernel to use updated packages.
#   DEPRECATION: Legacy editable install of cnnClassifier==0.0.0 from file:///E:/KrishNair/Kidney_Disease_Classification_Deep_Learning_Project (setup.py develop) is deprecated. pip 25.0 will enforce this behaviour change. A possible replacement is to add a pyproject.toml or enable --use-pep517, and use setuptools >= 64. If the resulting installation is not behaving as expected, try using --config-settings editable_mode=compat. Please consult the setuptools documentation for more information. Discussion can be found at https://github.com/pypa/pip/issues/11457

# %%
from cnnClassifier.constants import *
from cnnClassifier.utils.common import read_yaml, create_directories

# %%
import cnnClassifier
print(cnnClassifier)
# Out:
# <module 'cnnClassifier' from 'e:\\krishnair\\kidney_disease_classification_deep_learning_project\\src\\cnnClassifier\\__init__.py'>

# %%
pip install python-box
# Out:
# Collecting python-box
#   Downloading python_box-7.2.0-cp38-cp38-win_amd64.whl.metadata (8.0 kB)
# Downloading python_box-7.2.0-cp38-cp38-win_amd64.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ----------------------------------- ---- 1.0/1.2 MB 8.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.0/1.2 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 2.1 MB/s eta 0:00:00
# Installing collected packages: python-box
# Successfully installed python-box-7.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install PyYAML
# Out:
# Collecting PyYAML
#   Using cached PyYAML-6.0.3-cp38-cp38-win_amd64.whl.metadata (2.2 kB)
# Downloading PyYAML-6.0.3-cp38-cp38-win_amd64.whl (160 kB)
# Installing collected packages: PyYAML
# Successfully installed PyYAML-6.0.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install joblib
# Out:
# Collecting joblib
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Installing collected packages: joblib
# Successfully installed joblib-1.4.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install ensure
# Out:
# Collecting ensure
#   Downloading ensure-1.0.4-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: six>=1.11.0 in c:\users\pc\.conda\envs\kidney\lib\site-packages (from ensure) (1.16.0)
# Downloading ensure-1.0.4-py3-none-any.whl (15 kB)
# Installing collected packages: ensure
# Successfully installed ensure-1.0.4
# Note: you may need to restart the kernel to use updated packages.

# %%
from cnnClassifier.constants import *
from cnnClassifier.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)

        create_directories([self.config.artifacts_root])


    
    def get_data_ingestion_config(self) -> DataIngestionConfig:
        config = self.config.data_ingestion

        create_directories([config.root_dir])

        data_ingestion_config = DataIngestionConfig(
            root_dir=config.root_dir,
            source_URL=config.source_URL,
            local_data_file=config.local_data_file,
            unzip_dir=config.unzip_dir 
        )

        return data_ingestion_config

# %%
from cnnClassifier.entity.config_entity import DataIngestionConfig

# %%
from cnnClassifier.constants import *
from cnnClassifier.utils.common import read_yaml, create_directories
from cnnClassifier.entity.config_entity import DataIngestionConfig

# %%
print(CONFIG_FILE_PATH)
print(PARAMS_FILE_PATH)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(CONFIG_FILE_PATH)
#       2 print(PARAMS_FILE_PATH)
#
# NameError: name 'CONFIG_FILE_PATH' is not defined

# %%
from cnnClassifier.constants import *

# %%
print(CONFIG_FILE_PATH)
print(PARAMS_FILE_PATH)
# Out:
# config\config.yaml
# params.yaml

# %%
from cnnClassifier.utils.common import read_yaml, create_directories
from cnnClassifier.entity.config_entity import DataIngestionConfig

# %%
import os
import zipfile
import gdown
from cnnClassifier import logger
from cnnClassifier.utils.common import get_size

# %%
class DataIngestion:
    def __init__(self, config: DataIngestionConfig):
        self.config = config

    
    def download_file(self)-> str:
        '''
        Fetch data from the url
        '''

        try: 
            dataset_url = self.config.source_URL
            zip_download_dir = self.config.local_data_file
            os.makedirs("artifacts/data_ingestion", exist_ok=True)
            logger.info(f"Downloading data from {dataset_url} into file {zip_download_dir}")

            file_id = dataset_url.split("/")[-2]
            prefix = 'https://drive.google.com/uc?/export=download&id='
            gdown.download(prefix+file_id,zip_download_dir)

            logger.info(f"Downloaded data from {dataset_url} into file {zip_download_dir}")

        except Exception as e:
            raise e
        
    

    def extract_zip_file(self):
        """
        zip_file_path: str
        Extracts the zip file into the data directory
        Function returns None
        """
        unzip_path = self.config.unzip_dir
        os.makedirs(unzip_path, exist_ok=True)
        with zipfile.ZipFile(self.config.local_data_file, 'r') as zip_ref:
            zip_ref.extractall(unzip_path)

# %%
try:
    config = ConfigurationManager()
    data_ingestion_config = config.get_data_ingestion_config()
    data_ingestion = DataIngestion(config=data_ingestion_config)
    data_ingestion.download_file()
    data_ingestion.extract_zip_file()
except Exception as e:
    raise e
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       6     data_ingestion.extract_zip_file()
#       7 except Exception as e:
# ----> 8     raise e
#
# Cell In[1], line 2
#       1 try:
# ----> 2     config = ConfigurationManager()
#       3     data_ingestion_config = config.get_data_ingestion_config()
#       4     data_ingestion = DataIngestion(config=data_ingestion_config)
#
# NameError: name 'ConfigurationManager' is not defined

# %%
import os
print(os.getcwd())
print(os.path.exists("config/config.yaml"))
# Out:
# e:\KrishNair\Kidney_Disease_Classification_Deep_Learning_Project\research
# False

# %%
import os
os.chdir("..")

# %%
print(os.getcwd())
print(os.path.exists("config/config.yaml"))
# Out:
# e:\KrishNair\Kidney_Disease_Classification_Deep_Learning_Project
# True

# %%
from cnnClassifier.constants import *
from cnnClassifier.utils.common import read_yaml, create_directories
from cnnClassifier.entity.config_entity import DataIngestionConfig

# %%
import os
print(os.getcwd())
# Out:
# e:\KrishNair\Kidney_Disease_Classification_Deep_Learning_Project\research

# %%
# =========================
# 1. IMPORTS
# =========================

from cnnClassifier.constants import *
from cnnClassifier.utils.common import read_yaml, create_directories
from cnnClassifier.entity.config_entity import DataIngestionConfig
from cnnClassifier.components.data_ingestion import DataIngestion


# =========================
# 2. CONFIGURATION MANAGER
# =========================

class ConfigurationManager:
    def __init__(
        self,
        config_filepath=CONFIG_FILE_PATH,
        params_filepath=PARAMS_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)

        create_directories([self.config.artifacts_root])

    def get_data_ingestion_config(self) -> DataIngestionConfig:

        config = self.config.data_ingestion

        create_directories([config.root_dir])

        data_ingestion_config = DataIngestionConfig(
            root_dir=config.root_dir,
            source_URL=config.source_URL,
            local_data_file=config.local_data_file,
            unzip_dir=config.unzip_dir
        )

        return data_ingestion_config


# =========================
# 3. DATA INGESTION
# =========================

try:

    config = ConfigurationManager()

    data_ingestion_config = config.get_data_ingestion_config()

    data_ingestion = DataIngestion(
        config=data_ingestion_config
    )

    data_ingestion.download_file()

    data_ingestion.extract_zip_file()

except Exception as e:

    raise e
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 62
#      58     data_ingestion.extract_zip_file()
#      60 except Exception as e:
# ---> 62     raise e
#
# Cell In[2], line 48
#      42 # =========================
#      43 # 3. DATA INGESTION
#      44 # =========================
#      46 try:
# ---> 48     config = ConfigurationManager()
#      50     data_ingestion_config = config.get_data_ingestion_config()
#      52     data_ingestion = DataIngestion(
#      53         config=data_ingestion_config
#      54     )
#
# Cell In[2], line 21, in ConfigurationManager.__init__(self, config_filepath, params_filepath)
#      16 def __init__(
#      17     self,
#      18     config_filepath=CONFIG_FILE_PATH,
#      19     params_filepath=PARAMS_FILE_PATH):
# ---> 21     self.config = read_yaml(config_filepath)
#      22     self.params = read_yaml(params_filepath)
#      24     create_directories([self.config.artifacts_root])
#
# File c:\Users\PC\.conda\envs\kidney\lib\site-packages\ensure\main.py:872, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     869         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
#     870         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
# --> 872 return_val = self.f(*args, **kwargs)
#     873 if not isinstance(return_val, self.return_templ):
#     874     msg = "Return value of {f} of type {valt} " "does not match annotation type {t}"
#
# File e:\krishnair\kidney_disease_classification_deep_learning_project\src\cnnClassifier\utils\common.py:37, in read_yaml(path_to_yaml)
#      35     raise ValueError("yaml file is empty")
#      36 except Exception as e:
# ---> 37     raise e
#
# File e:\krishnair\kidney_disease_classification_deep_learning_project\src\cnnClassifier\utils\common.py:30, in read_yaml(path_to_yaml)
#      17 """reads yaml file and returns
#      18
#      19 Args:
#    (...)
#      27     ConfigBox: ConfigBox type
#      28 """
#      29 try:
# ---> 30     with open(path_to_yaml) as yaml_file:
#      31         content = yaml.safe_load(yaml_file)
#      32         logger.info(f"yaml file: {path_to_yaml} loaded successfully")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'config\\config.yaml'

# %%
from cnnClassifier.components.data_ingestion import DataIngestion

# %%
from cnnClassifier.components.data_ingestion import DataIngestion

# %%
try:
    config = ConfigurationManager()

    data_ingestion_config = config.get_data_ingestion_config()

    data_ingestion = DataIngestion(config=data_ingestion_config)

    data_ingestion.download_file()

    data_ingestion.extract_zip_file()

except Exception as e:
    raise e
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 13
#      10     data_ingestion.extract_zip_file()
#      12 except Exception as e:
# ---> 13     raise e
#
# Cell In[3], line 2
#       1 try:
# ----> 2     config = ConfigurationManager()
#       4     data_ingestion_config = config.get_data_ingestion_config()
#       6     data_ingestion = DataIngestion(config=data_ingestion_config)
#
# NameError: name 'ConfigurationManager' is not defined

# %%
from cnnClassifier.constants import *
from cnnClassifier.utils.common import read_yaml, create_directories
from cnnClassifier.entity.config_entity import DataIngestionConfig
from cnnClassifier.components.data_ingestion import DataIngestion


class ConfigurationManager:
    def __init__(
        self,
        config_filepath=CONFIG_FILE_PATH,
        params_filepath=PARAMS_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)

        create_directories([self.config.artifacts_root])

    def get_data_ingestion_config(self) -> DataIngestionConfig:

        config = self.config.data_ingestion

        create_directories([config.root_dir])

        data_ingestion_config = DataIngestionConfig(
            root_dir=config.root_dir,
            source_URL=config.source_URL,
            local_data_file=config.local_data_file,
            unzip_dir=config.unzip_dir
        )

        return data_ingestion_config


try:
    config = ConfigurationManager()

    data_ingestion_config = config.get_data_ingestion_config()

    data_ingestion = DataIngestion(
        config=data_ingestion_config
    )

    data_ingestion.download_file()

    data_ingestion.extract_zip_file()

except Exception as e:
    raise e
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 48
#      45     data_ingestion.extract_zip_file()
#      47 except Exception as e:
# ---> 48     raise e
#
# Cell In[2], line 35
#      31         return data_ingestion_config
#      34 try:
# ---> 35     config = ConfigurationManager()
#      37     data_ingestion_config = config.get_data_ingestion_config()
#      39     data_ingestion = DataIngestion(
#      40         config=data_ingestion_config
#      41     )
#
# Cell In[2], line 13, in ConfigurationManager.__init__(self, config_filepath, params_filepath)
#       8 def __init__(
#       9     self,
#      10     config_filepath=CONFIG_FILE_PATH,
#      11     params_filepath=PARAMS_FILE_PATH):
# ---> 13     self.config = read_yaml(config_filepath)
#      14     self.params = read_yaml(params_filepath)
#      16     create_directories([self.config.artifacts_root])
#
# File c:\Users\PC\.conda\envs\kidney\lib\site-packages\ensure\main.py:872, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     869         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
#     870         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
# --> 872 return_val = self.f(*args, **kwargs)
#     873 if not isinstance(return_val, self.return_templ):
#     874     msg = "Return value of {f} of type {valt} " "does not match annotation type {t}"
#
# File e:\krishnair\kidney_disease_classification_deep_learning_project\src\cnnClassifier\utils\common.py:37, in read_yaml(path_to_yaml)
#      35     raise ValueError("yaml file is empty")
#      36 except Exception as e:
# ---> 37     raise e
#
# File e:\krishnair\kidney_disease_classification_deep_learning_project\src\cnnClassifier\utils\common.py:30, in read_yaml(path_to_yaml)
#      17 """reads yaml file and returns
#      18
#      19 Args:
#    (...)
#      27     ConfigBox: ConfigBox type
#      28 """
#      29 try:
# ---> 30     with open(path_to_yaml) as yaml_file:
#      31         content = yaml.safe_load(yaml_file)
#      32         logger.info(f"yaml file: {path_to_yaml} loaded successfully")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'config\\config.yaml'

# %%
import os

print(os.getcwd())
print(os.path.exists("config/config.yaml"))
# Out:
# e:\KrishNair\Kidney_Disease_Classification_Deep_Learning_Project\research
# False

# %%
os.chdir("..")

# %%
print(os.getcwd())
print(os.path.exists("config/config.yaml"))
# Out:
# e:\KrishNair\Kidney_Disease_Classification_Deep_Learning_Project
# True

# %%
from cnnClassifier.constants import *
from cnnClassifier.utils.common import read_yaml, create_directories
from cnnClassifier.entity.config_entity import DataIngestionConfig
from cnnClassifier.components.data_ingestion import DataIngestion


class ConfigurationManager:
    def __init__(
        self,
        config_filepath=CONFIG_FILE_PATH,
        params_filepath=PARAMS_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)

        create_directories([self.config.artifacts_root])

    def get_data_ingestion_config(self) -> DataIngestionConfig:

        config = self.config.data_ingestion

        create_directories([config.root_dir])

        data_ingestion_config = DataIngestionConfig(
            root_dir=config.root_dir,
            source_URL=config.source_URL,
            local_data_file=config.local_data_file,
            unzip_dir=config.unzip_dir
        )

        return data_ingestion_config


try:
    config = ConfigurationManager()

    data_ingestion_config = config.get_data_ingestion_config()

    data_ingestion = DataIngestion(
        config=data_ingestion_config
    )

    data_ingestion.download_file()

    data_ingestion.extract_zip_file()

except Exception as e:
    raise e
# Out:
# [2026-09-07 02:55:43,722: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2026-09-07 02:55:43,733: INFO: common: yaml file: params.yaml loaded successfully]
# ---------------------------------------------------------------------------
# BoxValueError                             Traceback (most recent call last)
# File e:\krishnair\kidney_disease_classification_deep_learning_project\src\cnnClassifier\utils\common.py:33, in read_yaml(path_to_yaml)
#      32         logger.info(f"yaml file: {path_to_yaml} loaded successfully")
# ---> 33         return ConfigBox(content)
#      34 except BoxValueError:
#
# File c:\Users\PC\.conda\envs\kidney\lib\site-packages\box\box.py:284, in box.box.Box.__init__()
#
# BoxValueError: Cannot extrapolate Box from string
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 48
#      45     data_ingestion.extract_zip_file()
#      47 except Exception as e:
# ---> 48     raise e
#
# Cell In[6], line 35
#      31         return data_ingestion_config
#      34 try:
# ---> 35     config = ConfigurationManager()
#      37     data_ingestion_config = config.get_data_ingestion_config()
#      39     data_ingestion = DataIngestion(
#      40         config=data_ingestion_config
#      41     )
#
# Cell In[6], line 14, in ConfigurationManager.__init__(self, config_filepath, params_filepath)
#       8 def __init__(
#       9     self,
#      10     config_filepath=CONFIG_FILE_PATH,
#      11     params_filepath=PARAMS_FILE_PATH):
#      13     self.config = read_yaml(config_filepath)
# ---> 14     self.params = read_yaml(params_filepath)
#      16     create_directories([self.config.artifacts_root])
#
# File c:\Users\PC\.conda\envs\kidney\lib\site-packages\ensure\main.py:872, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     869         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
#     870         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
# --> 872 return_val = self.f(*args, **kwargs)
#     873 if not isinstance(return_val, self.return_templ):
#     874     msg = "Return value of {f} of type {valt} " "does not match annotation type {t}"
#
# File e:\krishnair\kidney_disease_classification_deep_learning_project\src\cnnClassifier\utils\common.py:35, in read_yaml(path_to_yaml)
#      33         return ConfigBox(content)
#      34 except BoxValueError:
# ---> 35     raise ValueError("yaml file is empty")
#      36 except Exception as e:
#      37     raise e
#
# ValueError: yaml file is empty

# %%
import yaml

with open(CONFIG_FILE_PATH, "r", encoding="utf-8") as f:
    content = yaml.safe_load(f)

print("TYPE:", type(content))
print("CONTENT:", content)
# Out:
# TYPE: <class 'dict'>
# CONTENT: {'artifacts_root': 'artifacts', 'data_ingestion': {'root_dir': 'artifacts/data_ingestion', 'source_URL': 'https://drive.google.com/file/d/1uuUV6qlbmSedb1GSqR0YfUwdZxFijNAH/view?usp=drive_link', 'local_data_file': 'artifacts/data_ingestion/data.zip', 'unzip_dir': 'artifacts/data_ingestion'}}

# %%
from cnnClassifier.constants import *
from cnnClassifier.utils.common import read_yaml, create_directories
from cnnClassifier.entity.config_entity import DataIngestionConfig
from cnnClassifier.components.data_ingestion import DataIngestion

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath=CONFIG_FILE_PATH,
        params_filepath=PARAMS_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)

        create_directories([self.config.artifacts_root])

    def get_data_ingestion_config(self) -> DataIngestionConfig:
        config = self.config.data_ingestion

        create_directories([config.root_dir])

        data_ingestion_config = DataIngestionConfig(
            root_dir=config.root_dir,
            source_URL=config.source_URL,
            local_data_file=config.local_data_file,
            unzip_dir=config.unzip_dir
        )

        return data_ingestion_config

# %%
config = ConfigurationManager()

data_ingestion_config = config.get_data_ingestion_config()

print(data_ingestion_config)
# Out:
# [2026-09-07 03:04:15,513: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2026-09-07 03:04:15,521: INFO: common: yaml file: params.yaml loaded successfully]
# [2026-09-07 03:04:15,527: INFO: common: created directory at: artifacts]
# [2026-09-07 03:04:15,531: INFO: common: created directory at: artifacts/data_ingestion]
# DataIngestionConfig(root_dir='artifacts/data_ingestion', source_URL='https://drive.google.com/file/d/1uuUV6qlbmSedb1GSqR0YfUwdZxFijNAH/view?usp=drive_link', local_data_file='artifacts/data_ingestion/data.zip', unzip_dir='artifacts/data_ingestion')

# %%
data_ingestion = DataIngestion(config=data_ingestion_config)
data_ingestion.download_file()
data_ingestion.extract_zip_file()
# Out:
# [2026-09-07 03:04:39,820: INFO: data_ingestion: Downloading data from https://drive.google.com/file/d/1uuUV6qlbmSedb1GSqR0YfUwdZxFijNAH/view?usp=drive_link into file artifacts/data_ingestion/data.zip]
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1uuUV6qlbmSedb1GSqR0YfUwdZxFijNAH
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1uuUV6qlbmSedb1GSqR0YfUwdZxFijNAH&confirm=t&uuid=53d9354e-65d9-4ef7-9f0c-b70dce864e52
# To: e:\KrishNair\Kidney_Disease_Classification_Deep_Learning_Project\artifacts\data_ingestion\data.zip
# 100%|██████████| 939M/939M [02:35<00:00, 6.03MB/s]
# [2026-09-07 03:07:18,167: INFO: data_ingestion: Downloaded data from https://drive.google.com/file/d/1uuUV6qlbmSedb1GSqR0YfUwdZxFijNAH/view?usp=drive_link into file artifacts/data_ingestion/data.zip]
